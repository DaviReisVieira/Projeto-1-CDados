# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Nome: Breno Quessie Barbosa de Lima
#
# Nome: Davi Reis Vieira de Souza

# %% [markdown]
# **Atenção:** Serão permitidos grupos de três pessoas, mas com uma rubrica mais exigente. Grupos deste tamanho precisarão fazer um questionário de avaliação de trabalho em equipe

# %% [markdown]
# ___
# Carregando algumas bibliotecas:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# **Em `filename`, coloque o nome do seu arquivo de dados!**

# %%
import os

filename = 'skybrasil.xlsx'
if filename in os.listdir():
    print(f'Encontrei o arquivo {filename}, tudo certo para prosseguir com a prova!')
else:
    print(f'Não encontrei o arquivo {filename} aqui no diretório {os.getcwd()}, será que você não baixou o arquivo?')
# Out:
# Encontrei o arquivo skybrasil.xlsx, tudo certo para prosseguir com a prova!

# %% [markdown]
# Carregando a base de dados com os tweets classificados como relevantes e não relevantes:

# %%
train = pd.read_excel(filename)
train.head(5)
# Out:
#                                          Treinamento  Classificação
# 0  rt @riffelviviane: @pdrobranco @umagremistaa__...              1
# 1  desde agosto reclamando. @skybrasil  desrespei...              1
# 2  @jugomes86 @skyresponde @luciano89168490 @sky ...              0
# 3  a @skyresponde @skybrasil está ligando pra o t...              1
# 4  dm onde? pq não consigo enviar nem pra vcs nem...              1

# %%
test = pd.read_excel(filename, sheet_name = 'Teste')
test.head(5)
# Out:
#    Classificação                                              Teste
# 0            0.0  @aguzzolimarco @maurinhodutra @skybrasil @sbto...
# 1            0.0  @skybrasil me contrata, prometo total dedicaçã...
# 2            1.0  @skybrasil liga mesmo. quanto mais ligações me...
# 3            1.0           @michelsoares80 @skybrasil tá complicado
# 4            0.0  rt @skybrasil: #devoltaprahogwarts\nhoje é dia...

# %%
train['Classificação'].value_counts()
# Out:
# 1    222
# 0     78
# Name: Classificação, dtype: int64

# %%
test['Classificação'].value_counts()
# Out:
# 1.0    40
# 0.0    34
# Name: Classificação, dtype: int64

# %% [markdown]
# ___
# ## Classificador automático de sentimento

# %% [markdown]
# Faça aqui uma descrição do seu produto e o que considerou como relevante ou não relevante na classificação dos tweets.
#
# ESCREVA AQUI...

# %% [markdown]
# ___
# ### Montando um Classificador Naive-Bayes
#
# Considerando apenas as mensagens da planilha Treinamento, ensine  seu classificador.

# %% [markdown]
# ___
# ### Verificando a performance do Classificador
#
# Agora você deve testar o seu classificador com a base de Testes.

# %% [markdown]
# ___
# ### Concluindo

# %% [markdown]
# ___
# ## Aperfeiçoamento:
#
# Os trabalhos vão evoluir em conceito dependendo da quantidade de itens avançados:
#
# * Limpar: \n, :, ", ', (, ), etc SEM remover emojis
# * Corrigir separação de espaços entre palavras e emojis ou entre emojis e emojis
# * Propor outras limpezas e transformações que não afetem a qualidade da informação ou classificação
# * Criar categorias intermediárias de relevância baseadas na probabilidade: ex.: muito relevante, relevante, neutro, irrelevante, muito irrelevante (3 categorias: C, mais categorias conta para B)
# * Explicar por que não posso usar o próprio classificador para gerar mais amostras de treinamento
# * Propor diferentes cenários para Naïve Bayes fora do contexto do projeto
# * Sugerir e explicar melhorias reais com indicações concretas de como implementar (indicar como fazer e indicar material de pesquisa)
# * Montar um dashboard que realiza análise de sentimento e visualiza estes dados

# %% [markdown]
# ___
# ## Referências

# %% [markdown]
# [Naive Bayes and Text Classification](https://arxiv.org/pdf/1410.5329.pdf)  **Mais completo**
#
# [A practical explanation of a Naive Bayes Classifier](https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/) **Mais simples**
